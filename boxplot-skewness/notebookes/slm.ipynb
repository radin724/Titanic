# %%
import numpy as np
import pandas as pd
from scipy.stats import skew
import seaborn as sns
import matplotlib.pyplot as plt 
df = pd.read_csv("bodyPerformance.csv")
df.drop(['class', 'gender'], axis=1, inplace=True)
df.head()
# Out:
#     age  height_cm  weight_kg  body fat_%  diastolic  systolic  gripForce  \
# 0  27.0      172.3      75.24        21.3       80.0     130.0       54.9
# 1  25.0      165.0      55.80        15.7       77.0     126.0       36.4
# 2  31.0      179.6      78.00        20.1       92.0     152.0       44.8
# 3  32.0      174.5      71.10        18.4       76.0     147.0       41.4
# 4  28.0      173.8      67.70        17.1       70.0     127.0       43.5
#
#    sit and bend forward_cm  sit-ups counts  broad jump_cm
# 0                     18.4            60.0          217.0
# 1                     16.3            53.0          229.0
# 2                     12.0            49.0          181.0
# 3                     15.2            53.0          219.0
# 4                     27.1            45.0          217.0

# %%
df.skew()
# Out:
# age                        0.599896
# height_cm                 -0.186882
# weight_kg                  0.349805
# body fat_%                 0.361132
# diastolic                 -0.159637
# systolic                  -0.048654
# gripForce                  0.018456
# sit and bend forward_cm    0.785492
# sit-ups counts            -0.467830
# broad jump_cm             -0.422623
# dtype: float64

# %%
for col in df.columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower) | (df[col] > upper)]
    print(f"{col}: {outliers.shape[0]} نقطه پرت دارد.")
# Out:
# age: 0 نقطه پرت دارد.
# height_cm: 10 نقطه پرت دارد.
# weight_kg: 83 نقطه پرت دارد.
# body fat_%: 77 نقطه پرت دارد.
# diastolic: 54 نقطه پرت دارد.
# systolic: 29 نقطه پرت دارد.
# gripForce: 3 نقطه پرت دارد.
# sit and bend forward_cm: 409 نقطه پرت دارد.
# sit-ups counts: 0 نقطه پرت دارد.
# broad jump_cm: 57 نقطه پرت دارد.

# %%
plt.figure(figsize=(6, 4))
plt.boxplot(df["height_cm"], vert=False) 
plt.title("Box Plot of height_cm ")
plt.ylabel("height_cm ")
plt.show()
